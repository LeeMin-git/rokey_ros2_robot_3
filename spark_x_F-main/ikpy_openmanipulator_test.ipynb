# %%
import ikpy.chain
import numpy as np
import ikpy.utils.plot as plot_utils
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/min/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import math

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("openmanipulator_sub.URDF")

# %%
target_position = [ 0.1, -0.2, 0.1]

# %%
print("The angles of each joints are : ", my_chain.inverse_kinematics(target_position))
# Out:
# The angles of each joints are :  [ 0.00379527  1.39177023 -2.29585393  0.        ]

# %%
real_frame = my_chain.forward_kinematics(my_chain.inverse_kinematics(target_position))
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_position))
# Out:
# Computed position vector : [ 9.99999898e-02 -8.03039548e-17  9.99999668e-02], original position vector : [0.1, -0.2, 0.1]

# %%
# Optional: support for 3D plotting in the NB
# If there is a matplotlib error, uncomment the next line, and comment the line below it.
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_position), ax, target=target_position)
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/registry.py:413, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     412 try:
# --> 413     return self.resolve_backend(gui_or_backend)
#     414 except Exception:  # KeyError ?
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/registry.py:375, in BackendRegistry.resolve_backend(self, backend)
#     374 if gui is None:
# --> 375     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     377 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[41], line 4
#       1 # Optional: support for 3D plotting in the NB
#       2 # If there is a matplotlib error, uncomment the next line, and comment the line below it.
#       3 # %matplotlib inline
# ----> 4 get_ipython().run_line_magic('matplotlib', 'widget')
#       5 import matplotlib.pyplot as plt
#       6 fig, ax = plot_utils.init_3d_figure()
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3665, in InteractiveShell.enable_matplotlib(self, gui)
#    3662     import matplotlib_inline.backend_inline
#    3664 from IPython.core import pylabtools as pt
# -> 3665 gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3667 if gui != None:
#    3668     # If we have our first gui selection, store it
#    3669     if self.pylab_gui_select is None:
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:349, in find_gui_and_backend(gui, gui_select)
#     347 else:
#     348     gui = _convert_gui_to_matplotlib(gui)
# --> 349     backend, gui = backend_registry.resolve_gui_or_backend(gui)
#     351 gui = _convert_gui_from_matplotlib(gui)
#     352 return gui, backend
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/registry.py:415, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     413     return self.resolve_backend(gui_or_backend)
#     414 except Exception:  # KeyError ?
# --> 415     raise RuntimeError(
#     416         f"'{gui_or_backend} is not a recognised GUI loop or backend name")
#
# RuntimeError: 'widget is not a recognised GUI loop or backend name

# %%
# !ls openmanipulator.URDF
# Out:
# ls: cannot access 'openmanipulator.URDF': No such file or directory

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("../resources/openmanipulator.URDF")

# %%
target_position = [ 0.2, 0, 0]

# %%
joints = my_chain.inverse_kinematics(target_position)
print("The angles of each joints are : ", joints)
# Out:
# The angles of each joints are :  [-1.78305541e-16  9.19959007e-01 -1.37792872e+00 -1.03324139e+00
#   0.00000000e+00]

# %%
th_delta = math.atan2(0.024, 0.128)

# %%
joints= [0, 1.57 - th_delta, -(1.57 - th_delta), 0, 0]
# joints= [0] * 5

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(joints, ax, target=target_position)

ax.set_xlim(-0.2, 0.2)
ax.set_ylim(-0.2, 0.2)
ax.set_zlim(-0.2, 0.2)
# Out:
# (-0.2, 0.2)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
my_chain.inverse_kinematics(target_position)
# Out:
# array([-1.78305541e-16,  9.19959007e-01, -1.37792872e+00, -1.03324139e+00,
#         0.00000000e+00])

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_position), ax, target=target_position)
# my_chain.goto(target_position, 1., wait=True)
# my_chain.plot(my_chain.joints_position, ax, target=target_position)

plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)

ax.set_xlim(-0.2, 0.2)
ax.set_ylim(-0.2, 0.2)
ax.set_zlim(-0.2, 0.2)
# Out:
# (-0.2, 0.2)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
